# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../resources/data_p.csv")

# %%
df.head()
# Out:
#          ID Diagnosis  radius mean  radius standard error  radius worst  \
# 0    842517         M        20.57                  17.77        132.90
# 1  84300903         M        19.69                  21.25        130.00
# 2  84348301         M        11.42                  20.38         77.58
# 3  84358402         M        20.29                  14.34        135.10
# 4    843786         M        12.45                  15.70         82.57
#
#    texture mean  texture standard error  texture worst  perimeter mean  \
# 0        1326.0                 0.08474        0.07864          0.0869
# 1        1203.0                 0.10960        0.15990          0.1974
# 2         386.1                 0.14250        0.28390          0.2414
# 3        1297.0                 0.10030        0.13280          0.1980
# 4         477.1                 0.12780        0.17000          0.1578
#
#    perimeter standard error  ...  concavity worst  concave mean  \
# ...

# %%
df.shape
# Out:
# (568, 32)

# %%
df.describe()
# Out:
#                  ID  radius mean  radius standard error  radius worst  \
# count  5.680000e+02   568.000000             568.000000    568.000000
# mean   3.042382e+07    14.120491              19.305335     91.914754
# std    1.251246e+08     3.523416               4.288506     24.285848
# min    8.670000e+03     6.981000               9.710000     43.790000
# 25%    8.692225e+05    11.697500              16.177500     75.135000
# 50%    9.061570e+05    13.355000              18.855000     86.210000
# 75%    8.825022e+06    15.780000              21.802500    103.875000
# max    9.113205e+08    28.110000              39.280000    188.500000
#
#        texture mean  texture standard error  texture worst  perimeter mean  \
# count    568.000000              568.000000     568.000000      568.000000
# mean     654.279754                0.096321       0.104036        0.088427
# std      351.923751                0.014046       0.052355        0.079294
# ...

# %%
sns.clustermap(df.corr())

# %%
sns.pairplot(df, hue="Diagnosis")

# %%
df.info()
